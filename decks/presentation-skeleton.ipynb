# %% [markdown]
# # This is a title

# %% [markdown]
# This is regular text

# %% [markdown]
# ## This is a section

# %%
from IPython.display import Image

# %%
Image("OpenMP-vs-IronArray.png")

# %% [markdown]
# That' all folks
